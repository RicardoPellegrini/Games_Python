# %% [markdown]
# # Jogo da Velha

# %% [markdown]
# Jogo da velha construído em Python, utilizando funções, condicionais, loops e tratando todos os erros que podem surgir durante esse jogo.

# %% [markdown]
# ### Criando funções para nosso programa principal

# %%
# Mostrando tabuleiro
def tabuleiro():
    global pos
    return f' {pos[0]} | {pos[1]} | {pos[2]} \n___________\n ' \
           f'{pos[3]} | {pos[4]} | {pos[5]} \n___________\n' \
           f' {pos[6]} | {pos[7]} | {pos[8]} \n'

# %%
# Escolhendo o simbolo entre 'X' e 'O'
def definir_simbolo():
    global simbolo
    while simbolo not in ['X', 'O']:
        simbolo = input("Escolha entre 'X' e 'O': ").upper().strip()
    return f"Seu simbolo é '{simbolo}'"

# %%
# Definindo a posição a jogar
def jogada():
    global simbolo, pos
    jog_pos = input('Digite uma posicao de 1 a 9: ')
    while True:
        if jog_pos not in [str(num) for num in range(1, 10)]:
            jog_pos = input('Deve ser inserido um numero inteiro de 1 a 9: ')
        elif pos[int(jog_pos)-1] != '-':
            jog_pos = input('Essa posicao ja foi escolhida, escolha outra: ')
        else:
            jog_pos = int(jog_pos)
            break
    pos[jog_pos-1] = simbolo
    return tabuleiro()

# %%
# Verificando vitoria ou empate
def verif_vitoria():
    global simbolo, pos, resultado
    if pos[0] == pos[1] == pos[2] == simbolo\
            or pos[3] == pos[4] == pos[5] == simbolo\
            or pos[6] == pos[7] == pos[8] == simbolo:
        resultado = 'Vitoria'
        return f"Vitoria do simbolo '{simbolo}' pela linha!"
    elif pos[0] == pos[3] == pos[6] == simbolo\
            or pos[1] == pos[4] == pos[7] == simbolo \
            or pos[2] == pos[5] == pos[8] == simbolo:
        resultado = 'Vitoria'
        return f"Vitoria do simbolo '{simbolo}' pela coluna!"
    elif pos[0] == pos[4] == pos[8] == simbolo \
            or pos[6] == pos[4] == pos[2] == simbolo:
        resultado = 'Vitoria'
        return f"Vitoria do simbolo '{simbolo}' pela diagonal!"
    else:
        if pos.count('-') == 0:
            resultado = 'Empate'
            return 'O jogo empatou!'
        else:
            pass

# %%
# Passando a vez para o outro jogador
def passar_vez():
    global simbolo
    if simbolo == 'X':
        simbolo = 'O'
    else:
        simbolo = 'X'
    return f"Agora é a vez do '{simbolo}'"

# %% [markdown]
# ### Agrupando todas as funções criadas, formando nosso programa principal

# %%
# Estrutura geral do jogo
def jogo_da_velha():
    global resultado, simbolo, pos
    while True:
        pos = ['-' for i in range(9)]
        resultado = 0
        simbolo = 0
        print('--------------------------------')
        print('SEJA BEM-VINDO AO JOGO DA VELHA!')
        print('--------------------------------')
        print(tabuleiro())
        print(definir_simbolo())
        while True:
            print(jogada())
            print(verif_vitoria())
            if resultado == 'Vitoria' or resultado == 'Empate':
                print('Fim de jogo')
                break
            else:
                print(passar_vez())
        while True:
            retry = input('Você deseja jogar novamente? [S/N] ').upper().strip()[0]
            if retry not in ['S', 'N']:
                retry = input('Você deseja jogar novamente? [S/N] ').upper().strip()[0]
            else:
                break
        if retry == 'N':
            print('JOGO FINALIZADO, ATÉ A PRÓXIMA!!')
            break

# %% [markdown]
# ### Chamada para início do Jogo da Velha

# %%
jogo_da_velha()
# Out:
# --------------------------------
# SEJA BEM-VINDO AO JOGO DA VELHA!
# --------------------------------
#  - | - | -
# ___________
#  - | - | -
# ___________
#  - | - | -
#
# Escolha entre 'X' e 'O': e
# Escolha entre 'X' e 'O': r
# Escolha entre 'X' e 'O': x
# Seu simbolo é 'X'
# Digite uma posicao de 1 a 9: 10
# Deve ser inserido um numero inteiro de 1 a 9: t
# Deve ser inserido um numero inteiro de 1 a 9: 5
#  - | - | -
# ___________
#  - | X | -
# ___________
#  - | - | -
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 3
#  - | - | O
# ___________
#  - | X | -
# ___________
#  - | - | -
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 4
#  - | - | O
# ___________
#  X | X | -
# ___________
#  - | - | -
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 2
#  - | O | O
# ___________
#  X | X | -
# ___________
#  - | - | -
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 1
#  X | O | O
# ___________
#  X | X | -
# ___________
#  - | - | -
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 9
#  X | O | O
# ___________
#  X | X | -
# ___________
#  - | - | O
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 6
#  X | O | O
# ___________
#  X | X | X
# ___________
#  - | - | O
#
# Vitoria do simbolo 'X' pela linha!
# Fim de jogo
# Você deseja jogar novamente? [S/N] r
# Você deseja jogar novamente? [S/N] talvez
# Você deseja jogar novamente? [S/N] s
# --------------------------------
# SEJA BEM-VINDO AO JOGO DA VELHA!
# --------------------------------
#  - | - | -
# ___________
#  - | - | -
# ___________
#  - | - | -
#
# Escolha entre 'X' e 'O': o
# Seu simbolo é 'O'
# Digite uma posicao de 1 a 9: 9
#  - | - | -
# ___________
#  - | - | -
# ___________
#  - | - | O
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 2
#  - | X | -
# ___________
#  - | - | -
# ___________
#  - | - | O
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 4
#  - | X | -
# ___________
#  O | - | -
# ___________
#  - | - | O
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 7
#  - | X | -
# ___________
#  O | - | -
# ___________
#  X | - | O
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 8
#  - | X | -
# ___________
#  O | - | -
# ___________
#  X | O | O
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 6
#  - | X | -
# ___________
#  O | - | X
# ___________
#  X | O | O
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 1
#  O | X | -
# ___________
#  O | - | X
# ___________
#  X | O | O
#
# None
# Agora é a vez do 'X'
# Digite uma posicao de 1 a 9: 5
#  O | X | -
# ___________
#  O | X | X
# ___________
#  X | O | O
#
# None
# Agora é a vez do 'O'
# Digite uma posicao de 1 a 9: 4
# Essa posicao ja foi escolhida, escolha outra: 1
# Essa posicao ja foi escolhida, escolha outra: t
# Deve ser inserido um numero inteiro de 1 a 9: 3
#  O | X | O
# ___________
#  O | X | X
# ___________
#  X | O | O
#
# O jogo empatou!
# Fim de jogo
# Você deseja jogar novamente? [S/N] n
# JOGO FINALIZADO, ATÉ A PRÓXIMA!!
